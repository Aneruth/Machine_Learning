# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import csv 
# %matplotlib inline

# %%
df1 = pd.read_csv('/Users/aneruthmohanasundaram/Documents/Python Exe/Datasets/iris.csv',index_col=0)
df1.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
df2 = pd.read_csv('/Users/aneruthmohanasundaram/Documents/Python Exe/Datasets/tips.csv')
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df1['SepalLengthCm'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
# Creating own kind of plot 
df1['SepalLengthCm'].plot(kind='hist',bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df3 = pd.read_csv('new_rec.csv',index_col=0)
df3.drop(['g'],axis=1,inplace=True)
df3.head()
# Out:
#            b      c     d     e     f
# a
# 0.123  1.543  2.345  4.33  1.12  0.56
# 1.450 -1.230  2.000  9.10  2.00  6.00
# 1.340  1.460  2.120  1.13  3.13  2.36
# 3.450  2.440  1.230  1.50  0.40  0.60
# 2.980  4.230  1.300  3.28  1.25  4.60

# %%
df3.plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='a'>

# %%
df3.plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df3.plot.scatter(x='c',y='e',s=df3['f']*45)
# Out:
# <AxesSubplot:xlabel='c', ylabel='e'>

# %%
df3.plot.box()
# Out:
# <AxesSubplot:>

# %%
  df = pd.DataFrame(np.random.randn(50,2),columns=['a','b'])
  df.head()
# Out:
#           a         b
# 0 -0.570416 -0.106827
# 1  0.704199 -0.147828
# 2 -0.070857  0.071837
# 3 -0.137876 -0.462430
# 4 -0.890461  0.643300

# %%
df2.plot.hexbin(x='total_bill',y='tip',gridsize=10)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
 df.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>
